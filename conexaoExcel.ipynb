# %% [markdown]
# # <center> 💻 Convertendo Excel para JSON 💻 <center>

# %% [markdown]
# ## Importando as bibliotecas 📕

# %%
import pandas as pd
import json

# %% [markdown]
# ### Pegando o excel

# %%
df = pd.read_excel('../Relação de Salas 2024.xlsx')

# %% [markdown]
# ### Transformando Excel em Json

# %%
jsonData = df.to_dict(orient='records')

# Converte JSON string para DataFrame
data_array = json.dumps(jsonData, indent=4)

# Exibe o DataFrame
print(data_array)
# Out:
# [
#     {
#         "Sala": 101,
#         "Andar": "1\u00ba",
#         "Quantidade": 8,
#         "Observa\u00e7\u00e3o": "Com TV",
#         "Unnamed: 4": NaN
#     },
#     {
#         "Sala": 102,
#         "Andar": "1\u00ba",
#         "Quantidade": 2,
#         "Observa\u00e7\u00e3o": "Psic\u00f3loga",
#         "Unnamed: 4": NaN
#     },
#     {
#         "Sala": 103,
#         "Andar": "1\u00ba",
#         "Quantidade": 4,
#         "Observa\u00e7\u00e3o": "Sem TV",
#         "Unnamed: 4": NaN
#     },
#     {
#         "Sala": 104,
#         "Andar": "1\u00ba",
#         "Quantidade": 4,
#         "Observa\u00e7\u00e3o": "Sem TV",
#         "Unnamed: 4": NaN
#     },
#     {
#         "Sala": 105,
#         "Andar": "1\u00ba",
#         "Quantidade": 4,
#         "Observa\u00e7\u00e3o": "Sem TV",
#         "Unnamed: 4": NaN
#     },
#     {
#         "Sala": 106,
#         "Andar": "1\u00ba",
#         "Quantidade": 4,
#         "Observa\u00e7\u00e3o": "Com TV",
# ...
